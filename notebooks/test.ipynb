# %% [markdown]
# # Test notebook

# %% [markdown]
# Testing class object and functions.  All aspects under active development.

# %%
import sproc
from sproc import sproc, Sproc, utils
% matplotlib inline

# %%
QC = Sproc(sp_name = "Quercus coccinea", lat_range = [40, 45], lon_range = [-100, -80],
            outdir = "/home/henrylandis/sproc")

# %%
QC.run()
# Out:
# . Found 64 records.

# %%
import pandas as pd
df = pd.read_csv("/home/henrylandis/sproc/Quercus_coccinea.csv")
df
# Out:
#              Species   Latitude  Longitude
# 0   Quercus_coccinea  41.306765 -81.560438
# 1   Quercus_coccinea  41.211792 -81.530083
# 2   Quercus_coccinea  42.945144 -89.933321
# 3   Quercus_coccinea  41.780232 -87.579766
# 4   Quercus_coccinea  40.952248 -80.170136
# ..               ...        ...        ...
# 59  Quercus_coccinea  41.950000 -88.433300
# 60  Quercus_coccinea  43.066667 -89.416667
# 61  Quercus_coccinea  40.758390 -82.515447
# 62  Quercus_coccinea  40.632462 -80.196115
# 63  Quercus_coccinea  41.128531 -80.045298
#
# [64 rows x 3 columns]

# %%
QE = Sproc(sp_name = "Quercus ellipsoidalis", lat_range = [40, 45], lon_range = [-100, -80],
            outdir = "/home/henrylandis/sproc")

# %%
QE.run()
# Out:
# .. Found 381 records.

# %%
df2 = pd.read_csv("/home/henrylandis/sproc/Quercus_ellipsoidalis.csv")
df2
# Out:
#                    Species   Latitude  Longitude
# 0    Quercus_ellipsoidalis  43.349428 -80.341764
# 1    Quercus_ellipsoidalis  43.326978 -80.295837
# 2    Quercus_ellipsoidalis  44.777100 -93.168380
# 3    Quercus_ellipsoidalis  44.810580 -93.107025
# 4    Quercus_ellipsoidalis  42.112939 -80.016953
# ..                     ...        ...        ...
# 376  Quercus_ellipsoidalis  44.968320 -93.215820
# 377  Quercus_ellipsoidalis  44.294170 -92.668890
# 378  Quercus_ellipsoidalis  44.980000 -93.263610
# 379  Quercus_ellipsoidalis  43.543920 -91.670700
# 380  Quercus_ellipsoidalis  43.966670 -91.766670
#
# [381 rows x 3 columns]

# %%
utils.hexmap(data = "/home/henrylandis/sproc/Quercus_ellipsoidalis.csv", figsize = (20, 5), gridsize = 20, alpha = 0.35)

# %%
utils.recmap(data = "/home/henrylandis/sproc/Quercus_ellipsoidalis.csv", figsize = (20, 5), bins = [10, 5], alpha = 0.35)

# %%
utils.kdemap(data = "/home/henrylandis/sproc/Quercus_coccinea.csv", figsize = (20, 5), levels = 50, alpha = 0.4)
# Out:
# /home/henrylandis/miniconda3/envs/py37/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
utils.calculate_overlay(QC.lats, QC.lons, QE.lats, QE.lons)

# %%
utils.plot_polygons_intersection("/home/henrylandis/sproc/Quercus_coccinea.csv", 
                                 "/home/henrylandis/sproc/Quercus_ellipsoidalis.csv")

# %%
utils.plot_polygons_separate("/home/henrylandis/sproc/Quercus_coccinea.csv", 
                             "/home/henrylandis/sproc/Quercus_ellipsoidalis.csv", sep = False)

# %%
utils.plot_polygons_separate("/home/henrylandis/sproc/Quercus_coccinea.csv", 
                             "/home/henrylandis/sproc/Quercus_ellipsoidalis.csv", sep = True)
